# %%
import numpy as np
import pandas as pd 
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Conv2D, MaxPooling2D, MaxPooling1D, Dense, Flatten, Dropout, SeparableConv1D
import matplotlib.pyplot as plt
import seaborn as sns

# %%
diagnosis_df = pd.read_csv('C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv', names=['Patient number', 'Diagnosis'])
diagnosis_df.head(4)
# Out:
#    Patient number Diagnosis
# 0             101      URTI
# 1             102   Healthy
# 2             103    Asthma
# 3             104      COPD

# %%
plt.figure(figsize=(10, 5))
sns.countplot(data=diagnosis_df, x='Diagnosis')
plt.show()

# %%
df_no_diagnosis = pd.read_csv('C:/Users/Admin/Documents/respiratory/demographic_info.txt', names = 
                 ['Patient number', 'Age', 'Sex' , 'Adult BMI (kg/m2)', 'Child Weight (kg)' , 'Child Height (cm)'],
                 delimiter = ' ')
df_no_diagnosis.head(5)
# Out:
#    Patient number    Age Sex  Adult BMI (kg/m2)  Child Weight (kg)  \
# 0             101   3.00   F                NaN               19.0
# 1             102   0.75   F                NaN                9.8
# 2             103  70.00   F              33.00                NaN
# 3             104  70.00   F              28.47                NaN
# 4             105   7.00   F                NaN               32.0
#
#    Child Height (cm)
# 0               99.0
# 1               73.0
# 2                NaN
# 3                NaN
# 4              135.0

# %%
df =  df_no_diagnosis.join(diagnosis_df.set_index('Patient number'), on = 'Patient number', how = 'left')
df.head(10)
# Out:
#    Patient number    Age Sex  Adult BMI (kg/m2)  Child Weight (kg)  \
# 0             101   3.00   F                NaN               19.0
# 1             102   0.75   F                NaN                9.8
# 2             103  70.00   F              33.00                NaN
# 3             104  70.00   F              28.47                NaN
# 4             105   7.00   F                NaN               32.0
# 5             106  73.00   F              21.00                NaN
# 6             107  75.00   F              33.70                NaN
# 7             108   3.00   M                NaN                NaN
# 8             109  84.00   F              33.53                NaN
# 9             110  75.00   M              25.21                NaN
#
#    Child Height (cm) Diagnosis
# 0               99.0      URTI
# 1               73.0   Healthy
# 2                NaN    Asthma
# 3                NaN      COPD
# 4              135.0      URTI
# 5                NaN      COPD
# 6                NaN      COPD
# 7                NaN      LRTI
# 8                NaN      COPD
# 9                NaN      COPD

# %%
root = 'C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/'
filenames = [s.split('.')[0] for s in os.listdir(path = root) if '.txt' in s]
def Extract_Annotation_Data(file_name, root):
    tokens = file_name.split('_')
    recording_info = pd.DataFrame(data = [tokens], columns = ['Patient number', 'Recording index', 'Chest location','Acquisition mode','Recording equipment'])
    recording_annotations = pd.read_csv(os.path.join(root, file_name + '.txt'), names = ['Start', 'End', 'Crackles', 'Wheezes'], delimiter= '\t')
    return (recording_info, recording_annotations)
i_list = []
rec_annotations = []
rec_annotations_dict = {}
for s in filenames:
    (i,a) = Extract_Annotation_Data(s, root)
    i_list.append(i)
    rec_annotations.append(a)
    rec_annotations_dict[s] = a
recording_info = pd.concat(i_list, axis = 0)
recording_info.head()
# Out:
#   Patient number Recording index Chest location Acquisition mode  \
# 0            101             1b1             Al               sc
# 0            101             1b1             Pr               sc
# 0            102             1b1             Ar               sc
# 0            103             2b2             Ar               mc
# 0            104             1b1             Al               sc
#
#   Recording equipment
# 0            Meditron
# 0            Meditron
# 0            Meditron
# 0            LittC2SE
# 0            Litt3200

# %%
class Diagnosis():
    def __init__ (self, id, diagnosis, image_path):
        self.id = id
        self.diagnosis = diagnosis 
        self.image_path = image_path

# %%
def get_wav_files():
    audio_path = 'C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/'
    files = [f for f in listdir(audio_path) if isfile(join(audio_path, f))]  #Gets all files in dir
    wav_files = [f for f in files if f.endswith('.wav')]  # Gets wav files 
    wav_files = sorted(wav_files)
    return wav_files, audio_path

# %%
def diagnosis_data():
    diagnosis = pd.read_csv('C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/patient_diagnosis.csv')
  
    wav_files, audio_path = get_wav_files()
    diag_dict = { 101 : "URTI"}  
    diagnosis_list = []
  
    for index , row in diagnosis.iterrows():
        diag_dict[row[0]] = row[1]     

    c = 0
    for f in wav_files:
        diagnosis_list.append(Diagnosis(c, diag_dict[int(f[:3])], audio_path+f))  
        c+=1  

    return diagnosis_list

# %%
import librosa
import librosa.display

def audio_features(filename): 
    sound, sample_rate = librosa.load(filename)
    stft = np.abs(librosa.stft(sound))  
 
    mfccs = np.mean(librosa.feature.mfcc(y=sound, sr=sample_rate, n_mfcc=40), axis=1)
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate), axis=1)
    
    # Pass 'y' and 'sr' parameters explicitly to melspectrogram
    mel = np.mean(librosa.feature.melspectrogram(y=sound, sr=sample_rate), axis=1)
    
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate), axis=1)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(sound), sr=sample_rate), axis=1)
    
    concat = np.concatenate((mfccs, chroma, mel, contrast, tonnetz))
    return concat

def data_points():
    labels = []
    images = []

    to_hot_one = {"COPD":0, "Healthy":1, "URTI":2, "Bronchiectasis":3, "Pneumonia":4, "Bronchiolitis":5, "Asthma":6, "LRTI":7}

    #count = 0
    for f in diagnosis_data():
        #print(count)
        labels.append(to_hot_one[f.diagnosis]) 
        images.append(audio_features(f.image_path))
        #count+=1

    return np.array(labels), np.array(images)

# %%
path = 'C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/filename_differences.txt'

diff = pd.read_csv(path, sep=" ", header=None, names=['file_names'])
diff.head(5)
# Out:
#                  file_names
# 0  '101_1b1_Al_sc_AKGC417L'
# 1  '101_1b1_Pr_sc_AKGC417L'
# 2  '102_1b1_Ar_sc_AKGC417L'
# 3  '105_1b1_Tc_sc_LittC2SE'
# 4  '108_1b1_Al_sc_LittC2SE'

# %%
df =  diff.join(diagnosis_df,how = 'left')
df.head(15)
# Out:
#                   file_names  Patient number       Diagnosis
# 0   '101_1b1_Al_sc_AKGC417L'             101            URTI
# 1   '101_1b1_Pr_sc_AKGC417L'             102         Healthy
# 2   '102_1b1_Ar_sc_AKGC417L'             103          Asthma
# 3   '105_1b1_Tc_sc_LittC2SE'             104            COPD
# 4   '108_1b1_Al_sc_LittC2SE'             105            URTI
# 5   '111_1b2_Tc_sc_LittC2SE'             106            COPD
# 6   '111_1b3_Tc_sc_LittC2SE'             107            COPD
# 7   '115_1b1_Ar_sc_LittC2SE'             108            LRTI
# 8   '116_1b2_Pl_sc_LittC2SE'             109            COPD
# 9   '116_1b2_Tc_sc_LittC2SE'             110            COPD
# 10  '119_1b1_Ar_sc_AKGC417L'             111  Bronchiectasis
# 11  '121_1b1_Tc_sc_LittC2SE'             112            COPD
# 12  '121_1p1_Tc_sc_LittC2SE'             113            COPD
# 13  '123_1b1_Al_sc_AKGC417L'             114            COPD
# 14  '125_1b1_Tc_sc_LittC2SE'             115            LRTI

# %%
x, sr = librosa.load('C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/101_1b1_Al_sc_Meditron.wav')

# Use the entire audio signal 'x' for mel spectrogram computation
S = librosa.feature.melspectrogram(y=x, sr=sr)

# %%
plt.figure(figsize=(10, 7))
plt.subplot(2,2,1)
librosa.display.specshow(librosa.power_to_db(S, ref=np.max))
plt.title('URTI Mel spectrogram')
plt.tight_layout()

# Use the entire audio signal 'x' for MFCC computation
T = librosa.feature.mfcc(y=x)
plt.subplot(2,2,2)
librosa.display.specshow(librosa.power_to_db(T, ref=np.max))
plt.title('URTI MFCC')
plt.tight_layout()

# %%
x1, _ = librosa.load('C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Al_sc_Litt3200.wav')
S1 = librosa.feature.melspectrogram(y=x1)  # Pass the audio signal 'x1' to melspectrogram

plt.figure(figsize=(10, 7))
plt.subplot(2, 2, 1)
librosa.display.specshow(librosa.power_to_db(S1, ref=np.max))
plt.title('COPD Mel spectrogram')
plt.tight_layout()

# Use the entire audio signal 'x1' for MFCC computation
T1 = librosa.feature.mfcc(y=x1)

plt.subplot(2, 2, 2)
librosa.display.specshow(librosa.power_to_db(T1, ref=np.max))
plt.title('COPD MFCC')
plt.tight_layout()

plt.show()

# %%
x1, _ = librosa.load('C:/Users/Admin/Documents/respiratory/Respiratory_Sound_Database/Respiratory_Sound_Database/audio_and_txt_files/104_1b1_Ar_sc_Litt3200.wav')
S1 = librosa.feature.melspectrogram(y=x1)  # Pass the audio signal 'x1' to melspectrogram

plt.figure(figsize=(10, 7))
plt.subplot(2, 2, 1)
librosa.display.specshow(librosa.power_to_db(S1, ref=np.max))
plt.title('Healthy Mel spectrogram')
plt.tight_layout()

# Use the entire audio signal 'x1' for MFCC computation
T1 = librosa.feature.mfcc(y=x1)

plt.subplot(2, 2, 2)
librosa.display.specshow(librosa.power_to_db(T1, ref=np.max))
plt.title('Healthy MFCC')
plt.tight_layout()

plt.show()

# %%
from sklearn.model_selection import train_test_split

def preprocessing(labels, images):    

  # Remove Asthma and LRTI
    images = np.delete(images, np.where((labels == 7) | (labels == 6))[0], axis=0) 
    labels = np.delete(labels, np.where((labels == 7) | (labels == 6))[0], axis=0)      

  # Split data
    X_train, X_test, y_train, y_test = train_test_split(images, labels, test_size=0.2, random_state=10)

  # Hot one encode the labels
    y_train = to_categorical(y_train)
    y_test = to_categorical(y_test)  

  # Format new data
    y_train = np.reshape(y_train, (y_train.shape[0], 6))
    X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
    y_test = np.reshape(y_test, (y_test.shape[0], 6))
    X_test = np.reshape(X_test, (X_test.shape[0], X_train.shape[1],  1))

    return X_train, X_test, y_train, y_test

# %%
from os import listdir
from os.path import isfile, join
from tensorflow.keras.utils import plot_model,to_categorical

labels, images = data_points()
X_train, X_test, y_train, y_test = preprocessing(labels, images)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(

# %%
model = Sequential()
model.add(Conv1D(64, kernel_size=5, activation='relu', input_shape=(193, 1)))

model.add(Conv1D(128, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(2)) 

model.add(SeparableConv1D(256, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(2)) 

model.add(SeparableConv1D(256, kernel_size=5, activation='relu'))
model.add(MaxPooling1D(2)) 

model.add(Dropout(0.5))
model.add(Flatten())

model.add(Dense(512, activation='relu'))   
model.add(Dense(6, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=70, batch_size=200, verbose=1)
# Out:
# Epoch 1/70
# 4/4 [==============================] - 6s 679ms/step - loss: 1.3298 - accuracy: 0.6344 - val_loss: 0.5580 - val_accuracy: 0.8967
# Epoch 2/70
# 4/4 [==============================] - 2s 493ms/step - loss: 0.6693 - accuracy: 0.8568 - val_loss: 0.4813 - val_accuracy: 0.8967
# Epoch 3/70
# 4/4 [==============================] - 2s 519ms/step - loss: 0.7365 - accuracy: 0.8568 - val_loss: 0.4240 - val_accuracy: 0.8967
# Epoch 4/70
# 4/4 [==============================] - 2s 598ms/step - loss: 0.5881 - accuracy: 0.8568 - val_loss: 0.4549 - val_accuracy: 0.8967
# Epoch 5/70
# 4/4 [==============================] - 2s 491ms/step - loss: 0.5777 - accuracy: 0.8568 - val_loss: 0.4507 - val_accuracy: 0.8967
# Epoch 6/70
# 4/4 [==============================] - 2s 497ms/step - loss: 0.5605 - accuracy: 0.8568 - val_loss: 0.4136 - val_accuracy: 0.8967
# Epoch 7/70
# 4/4 [==============================] - 2s 488ms/step - loss: 0.5455 - accuracy: 0.8568 - val_loss: 0.4123 - val_accuracy: 0.8967
# Epoch 8/70
# 4/4 [==============================] - 2s 489ms/step - loss: 0.5415 - accuracy: 0.8568 - val_loss: 0.4166 - val_accuracy: 0.8967
# Epoch 9/70
# 4/4 [==============================] - 2s 494ms/step - loss: 0.5343 - accuracy: 0.8568 - val_loss: 0.4073 - val_accuracy: 0.8967
# Epoch 10/70
# 4/4 [==============================] - 2s 503ms/step - loss: 0.5263 - accuracy: 0.8568 - val_loss: 0.4015 - val_accuracy: 0.8967
# Epoch 11/70
# 4/4 [==============================] - 2s 497ms/step - loss: 0.5220 - accuracy: 0.8568 - val_loss: 0.4001 - val_accuracy: 0.8967
# Epoch 12/70
# 4/4 [==============================] - 2s 490ms/step - loss: 0.5150 - accuracy: 0.8568 - val_loss: 0.3979 - val_accuracy: 0.8967
# Epoch 13/70
# 4/4 [==============================] - 2s 514ms/step - loss: 0.5124 - accuracy: 0.8568 - val_loss: 0.3907 - val_accuracy: 0.8967
# Epoch 14/70
# 4/4 [==============================] - 2s 504ms/step - loss: 0.5127 - accuracy: 0.8568 - val_loss: 0.3881 - val_accuracy: 0.8967
# Epoch 15/70
# 4/4 [==============================] - 2s 484ms/step - loss: 0.5059 - accuracy: 0.8568 - val_loss: 0.3839 - val_accuracy: 0.8967
# Epoch 16/70
# 4/4 [==============================] - 2s 485ms/step - loss: 0.4973 - accuracy: 0.8568 - val_loss: 0.3958 - val_accuracy: 0.8967
# Epoch 17/70
# 4/4 [==============================] - 2s 642ms/step - loss: 0.4939 - accuracy: 0.8568 - val_loss: 0.3806 - val_accuracy: 0.8967
# Epoch 18/70
# 4/4 [==============================] - 3s 684ms/step - loss: 0.4976 - accuracy: 0.8568 - val_loss: 0.3817 - val_accuracy: 0.8967
# Epoch 19/70
# 4/4 [==============================] - 3s 650ms/step - loss: 0.4832 - accuracy: 0.8568 - val_loss: 0.3798 - val_accuracy: 0.8967
# Epoch 20/70
# 4/4 [==============================] - 3s 639ms/step - loss: 0.4775 - accuracy: 0.8568 - val_loss: 0.3718 - val_accuracy: 0.8967
# Epoch 21/70
# 4/4 [==============================] - 3s 642ms/step - loss: 0.4691 - accuracy: 0.8568 - val_loss: 0.3738 - val_accuracy: 0.8967
# Epoch 22/70
# 4/4 [==============================] - 3s 659ms/step - loss: 0.4564 - accuracy: 0.8568 - val_loss: 0.3630 - val_accuracy: 0.8967
# Epoch 23/70
# 4/4 [==============================] - 3s 647ms/step - loss: 0.4540 - accuracy: 0.8568 - val_loss: 0.3662 - val_accuracy: 0.8967
# Epoch 24/70
# 4/4 [==============================] - 3s 682ms/step - loss: 0.4347 - accuracy: 0.8568 - val_loss: 0.3459 - val_accuracy: 0.8967
# Epoch 25/70
# 4/4 [==============================] - 3s 647ms/step - loss: 0.4326 - accuracy: 0.8581 - val_loss: 0.3411 - val_accuracy: 0.8967
# Epoch 26/70
# 4/4 [==============================] - 3s 662ms/step - loss: 0.4195 - accuracy: 0.8540 - val_loss: 0.3184 - val_accuracy: 0.8967
# Epoch 27/70
# 4/4 [==============================] - 3s 646ms/step - loss: 0.4037 - accuracy: 0.8554 - val_loss: 0.3068 - val_accuracy: 0.8859
# Epoch 28/70
# 4/4 [==============================] - 3s 644ms/step - loss: 0.3863 - accuracy: 0.8581 - val_loss: 0.3040 - val_accuracy: 0.8804
# Epoch 29/70
# 4/4 [==============================] - 3s 651ms/step - loss: 0.3721 - accuracy: 0.8554 - val_loss: 0.2804 - val_accuracy: 0.8859
# Epoch 30/70
# 4/4 [==============================] - 3s 646ms/step - loss: 0.3504 - accuracy: 0.8581 - val_loss: 0.2774 - val_accuracy: 0.8913
# Epoch 31/70
# 4/4 [==============================] - 3s 648ms/step - loss: 0.3524 - accuracy: 0.8718 - val_loss: 0.2529 - val_accuracy: 0.8967
# Epoch 32/70
# 4/4 [==============================] - 3s 652ms/step - loss: 0.3603 - accuracy: 0.8799 - val_loss: 0.2899 - val_accuracy: 0.8913
# Epoch 33/70
# 4/4 [==============================] - 3s 655ms/step - loss: 0.3465 - accuracy: 0.8663 - val_loss: 0.2617 - val_accuracy: 0.9185
# Epoch 34/70
# 4/4 [==============================] - 3s 649ms/step - loss: 0.3425 - accuracy: 0.8745 - val_loss: 0.2358 - val_accuracy: 0.9022
# Epoch 35/70
# 4/4 [==============================] - 3s 651ms/step - loss: 0.3194 - accuracy: 0.8731 - val_loss: 0.2305 - val_accuracy: 0.9076
# Epoch 36/70
# 4/4 [==============================] - 3s 643ms/step - loss: 0.3122 - accuracy: 0.8759 - val_loss: 0.2391 - val_accuracy: 0.9076
# Epoch 37/70
# 4/4 [==============================] - 3s 681ms/step - loss: 0.3128 - accuracy: 0.8868 - val_loss: 0.2189 - val_accuracy: 0.9076
# Epoch 38/70
# 4/4 [==============================] - 3s 664ms/step - loss: 0.2949 - accuracy: 0.8731 - val_loss: 0.2230 - val_accuracy: 0.9022
# Epoch 39/70
# 4/4 [==============================] - 3s 646ms/step - loss: 0.3005 - accuracy: 0.8718 - val_loss: 0.2236 - val_accuracy: 0.9185
# Epoch 40/70
# 4/4 [==============================] - 3s 714ms/step - loss: 0.2800 - accuracy: 0.8827 - val_loss: 0.2048 - val_accuracy: 0.9239
# Epoch 41/70
# 4/4 [==============================] - 6s 1s/step - loss: 0.2692 - accuracy: 0.8868 - val_loss: 0.2235 - val_accuracy: 0.9185
# Epoch 42/70
# 4/4 [==============================] - 3s 667ms/step - loss: 0.2641 - accuracy: 0.8950 - val_loss: 0.2048 - val_accuracy: 0.9076
# Epoch 43/70
# 4/4 [==============================] - 3s 730ms/step - loss: 0.2497 - accuracy: 0.8950 - val_loss: 0.2051 - val_accuracy: 0.9185
# Epoch 44/70
# 4/4 [==============================] - 3s 798ms/step - loss: 0.2671 - accuracy: 0.8936 - val_loss: 0.2215 - val_accuracy: 0.9185
# Epoch 45/70
# 4/4 [==============================] - 3s 806ms/step - loss: 0.2517 - accuracy: 0.8950 - val_loss: 0.2093 - val_accuracy: 0.9130
# Epoch 46/70
# 4/4 [==============================] - 3s 750ms/step - loss: 0.2483 - accuracy: 0.8854 - val_loss: 0.2239 - val_accuracy: 0.9185
# Epoch 47/70
# 4/4 [==============================] - 3s 887ms/step - loss: 0.2356 - accuracy: 0.8950 - val_loss: 0.2281 - val_accuracy: 0.9076
# Epoch 48/70
# 4/4 [==============================] - 3s 739ms/step - loss: 0.2380 - accuracy: 0.9018 - val_loss: 0.1982 - val_accuracy: 0.9239
# Epoch 49/70
# 4/4 [==============================] - 3s 801ms/step - loss: 0.2407 - accuracy: 0.8990 - val_loss: 0.1948 - val_accuracy: 0.9293
# Epoch 50/70
# 4/4 [==============================] - 3s 839ms/step - loss: 0.2341 - accuracy: 0.9113 - val_loss: 0.1938 - val_accuracy: 0.9239
# Epoch 51/70
# 4/4 [==============================] - 3s 671ms/step - loss: 0.2181 - accuracy: 0.9018 - val_loss: 0.1972 - val_accuracy: 0.9130
# Epoch 52/70
# 4/4 [==============================] - 3s 670ms/step - loss: 0.2235 - accuracy: 0.9154 - val_loss: 0.1913 - val_accuracy: 0.9239
# Epoch 53/70
# 4/4 [==============================] - 3s 703ms/step - loss: 0.2169 - accuracy: 0.9045 - val_loss: 0.1964 - val_accuracy: 0.9130
# Epoch 54/70
# 4/4 [==============================] - 3s 726ms/step - loss: 0.2078 - accuracy: 0.9209 - val_loss: 0.1816 - val_accuracy: 0.9239
# Epoch 55/70
# 4/4 [==============================] - 3s 775ms/step - loss: 0.1988 - accuracy: 0.9209 - val_loss: 0.1920 - val_accuracy: 0.9076
# Epoch 56/70
# 4/4 [==============================] - 3s 790ms/step - loss: 0.1943 - accuracy: 0.9222 - val_loss: 0.1913 - val_accuracy: 0.9076
# Epoch 57/70
# 4/4 [==============================] - 3s 745ms/step - loss: 0.1967 - accuracy: 0.9345 - val_loss: 0.1949 - val_accuracy: 0.9293
# Epoch 58/70
# 4/4 [==============================] - 3s 730ms/step - loss: 0.1933 - accuracy: 0.9236 - val_loss: 0.2002 - val_accuracy: 0.9022
# Epoch 59/70
# 4/4 [==============================] - 3s 711ms/step - loss: 0.1823 - accuracy: 0.9195 - val_loss: 0.1974 - val_accuracy: 0.9239
# Epoch 60/70
# 4/4 [==============================] - 3s 672ms/step - loss: 0.1902 - accuracy: 0.9236 - val_loss: 0.1911 - val_accuracy: 0.9130
# Epoch 61/70
# 4/4 [==============================] - 3s 753ms/step - loss: 0.1815 - accuracy: 0.9332 - val_loss: 0.1779 - val_accuracy: 0.9239
# Epoch 62/70
# 4/4 [==============================] - 3s 658ms/step - loss: 0.1968 - accuracy: 0.9291 - val_loss: 0.2118 - val_accuracy: 0.9022
# Epoch 63/70
# 4/4 [==============================] - 3s 700ms/step - loss: 0.1858 - accuracy: 0.9304 - val_loss: 0.1941 - val_accuracy: 0.9293
# Epoch 64/70
# 4/4 [==============================] - 3s 668ms/step - loss: 0.1737 - accuracy: 0.9222 - val_loss: 0.1763 - val_accuracy: 0.9293
# Epoch 65/70
# 4/4 [==============================] - 3s 663ms/step - loss: 0.1617 - accuracy: 0.9386 - val_loss: 0.1827 - val_accuracy: 0.9293
# Epoch 66/70
# 4/4 [==============================] - 3s 670ms/step - loss: 0.1687 - accuracy: 0.9359 - val_loss: 0.1994 - val_accuracy: 0.9076
# Epoch 67/70
# 4/4 [==============================] - 3s 666ms/step - loss: 0.1734 - accuracy: 0.9345 - val_loss: 0.1778 - val_accuracy: 0.9239
# Epoch 68/70
# 4/4 [==============================] - 3s 685ms/step - loss: 0.1615 - accuracy: 0.9263 - val_loss: 0.1802 - val_accuracy: 0.9239
# Epoch 69/70
# 4/4 [==============================] - 3s 652ms/step - loss: 0.1757 - accuracy: 0.9413 - val_loss: 0.2001 - val_accuracy: 0.9239
# Epoch 70/70
# 4/4 [==============================] - 3s 658ms/step - loss: 0.1616 - accuracy: 0.9250 - val_loss: 0.1819 - val_accuracy: 0.9076

# %%
def visualize_training(history, lw = 3):
    plt.figure(figsize=(10,6))
    plt.plot(history.history['accuracy'], label = 'training', marker = '*', linewidth = lw)
    plt.plot(history.history['val_accuracy'], label = 'validation', marker = 'o', linewidth = lw)
    plt.title('Training Accuracy vs Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend(fontsize = 'x-large')
    plt.show()

    plt.figure(figsize=(10,6))
    plt.plot(history.history['loss'], label = 'training', marker = '*', linewidth = lw)
    plt.plot(history.history['val_loss'], label = 'validation', marker = 'o', linewidth = lw)
    plt.title('Training Loss vs Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(fontsize = 'x-large')
    plt.show()
visualize_training(history)

# %%
from sklearn.metrics import roc_auc_score, classification_report, confusion_matrix
matrix_index = ["COPD", "Healthy", "URTI", "Bronchiectasis", "Pneumoina", "Bronchiolitis"]

preds = model.predict(X_test)
classpreds = np.argmax(preds, axis=1) # predicted classes 
y_testclass = np.argmax(y_test, axis=1) # true classes

cm = confusion_matrix(y_testclass, classpreds)
print(classification_report(y_testclass, classpreds, target_names=matrix_index))

# Get percentage value for each element of the matrix
cm_sum = np.sum(cm, axis=1, keepdims=True)
cm_perc = cm / cm_sum.astype(float) * 100
annot = np.empty_like(cm).astype(str)
nrows, ncols = cm.shape
for i in range(nrows):
    for j in range(ncols):
        c = cm[i, j]
        p = cm_perc[i, j]
        if i == j:
            s = cm_sum[i]
            annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
        elif c == 0:
            annot[i, j] = ''
        else:
            annot[i, j] = '%.1f%%\n%d' % (p, c)


# Display confusion matrix 
df_cm = pd.DataFrame(cm, index = matrix_index, columns = matrix_index)
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
fig, ax = plt.subplots(figsize=(10,7))
sns.heatmap(df_cm, annot=annot, fmt='')
# Out:
# 6/6 [==============================] - 1s 37ms/step
#                 precision    recall  f1-score   support
#
#           COPD       0.99      0.96      0.97       165
#        Healthy       0.50      0.43      0.46         7
#           URTI       0.20      0.25      0.22         4
# Bronchiectasis       1.00      0.50      0.67         4
#      Pneumoina       0.33      1.00      0.50         3
#  Bronchiolitis       0.00      0.00      0.00         1
#
#       accuracy                           0.91       184
#      macro avg       0.50      0.52      0.47       184
#   weighted avg       0.94      0.91      0.92       184
# <Axes: xlabel='Predicted', ylabel='Actual'>
